# %% [markdown]
# # Python, Jupyter Notebook, OpenCV 설치하고 영상을 프레임별로 출력해보기

# %% [markdown]
# ![image.png](attachment:aeafcdac-ebeb-47eb-8ac7-ef8b18941a49.png)

# %%
# 모듈 호출
import numpy as np
import cv2 as cv
import os

# %%
os.chdir('C:\\Users\\js\\Documents\\playground\\python_workspace\\computervision_tutorial')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\js\\Documents\\playground\\python_workspace\\computervision_tutorial'

# %%
# VideoCapture 객체 정의
cap = cv.VideoCapture('otter.avi')

# %%
# 프레임 너비/높이, 초당 프레임 수 확인
width = cap.get(cv.CAP_PROP_FRAME_WIDTH) # 또는 cap.get(3)
height = cap.get(cv.CAP_PROP_FRAME_HEIGHT) # 또는 cap.get(4)
fps = cap.get(cv.CAP_PROP_FPS) # 또는 cap.get(5)
print('프레임 너비: %d, 프레임 높이: %d, 초당 프레임 수: %d' %(width, height, fps))
# Out:
# 프레임 너비: 720, 프레임 높이: 400, 초당 프레임 수: 24

# %%
while cap.isOpened(): # cap 정상동작 확인
    ret, frame = cap.read()
    # 프레임이 올바르게 읽히면 ret은 True
    if not ret:
        print("프레임을 수신할 수 없습니다(스트림 끝?). 종료 중 ...")
        break
    frame = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
    cv.imshow('Otter', frame)
    if cv.waitKey(42) == ord('q'):
        break
# 작업 완료 후 해제
cap.release()
cv.destroyAllWindows()
# Out:
# 프레임을 수신할 수 없습니다(스트림 끝?). 종료 중 ...

# %% [markdown]
# 출처: https://foss4g.tistory.com/1612

# %% [markdown]
# 고찰:
# 연속적인 프레임을 제공하는 동영상을 각 프레임별로 분석해볼 수 있었다. 이후 각 프레임에 대해
# 컴퓨터비전 뿐만 아니라 이미지분류같은 머신러닝 알고리즘, Yolo같은 딥러닝 알고리즘을 확장/적용해볼 수 있을 것 같다.
